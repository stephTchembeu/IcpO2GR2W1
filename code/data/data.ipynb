# %%
import pandas as pd
df = pd.read_csv("/home/student/Documents/AIMS/review_block 2/supervised learning/assignments/assignment1/IcpO2GR2W1/code/data/Malaria-Data.csv")
df
# Out:
#      age  sex  fever  cold  rigor  fatigue  headace  bitter_tongue  vomitting  \
# 0      3    1      1     1      0        1        1              1          0
# 1      3    0      1     1      1        1        1              1          0
# 2      3    0      1     1      1        1        1              0          0
# 3      4    1      1     1      0        1        0              0          0
# 4      4    0      1     1      1        0        1              0          0
# ..   ...  ...    ...   ...    ...      ...      ...            ...        ...
# 332   71    0      1     1      0        1        0              1          1
# 333   71    0      1     0      0        0        1              0          0
# 334   74    1      1     0      0        0        0              0          0
# 335   76    0      0     1      0        0        1              0          1
# 336   77    1      1     1      1        0        1              0          0
#
# ...
